# %%
from transformers import T5ForConditionalGeneration, T5Tokenizer

model = T5ForConditionalGeneration.from_pretrained(
    "/content/drive/MyDrive/GoogleColab/EnChatbot/backend/models"
)

tokenizer = T5Tokenizer.from_pretrained(
    "/content/drive/MyDrive/GoogleColab/EnChatbot/backend/models"
)
# Out:
# ---------------------------------------------------------------------------
# HFValidationError                         Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/transformers/utils/hub.py in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, tqdm_class, **deprecated_kwargs)
#     436             # This is slightly better for only 1 file
# --> 437             hf_hub_download(
#     438                 path_or_repo_id,
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#      83             if arg_name in ["repo_id", "from_id", "to_id"]:
# ---> 84                 validate_repo_id(arg_value)
#      85
#
# ...

# %%
class FakeLlama:

    def __call__(self, prompt):

        print("=" * 80)
        print(prompt)
        print("=" * 80)

        return "[Llama response]"

# %%
# import necessary modules
from backend.services.grammar import GrammarService
from backend.services.memory import MemoryService
from backend.services.router import Router
from backend.services.explanation import ExplanationService
from backend.services.conversation import ConversationService


# build all services

llama = FakeLlama()
grammar_service = GrammarService(
    model,
    tokenizer
)
memory = MemoryService()
router = Router(memory)
explanation_service = ExplanationService(llama)
conversation_service = ConversationService(llama)

# %%
# logging
import logging

logging.basicConfig(
    level=logging.INFO
)

# %%
# test grammar correction feature
sentence = "She go to school yesterday."

result = grammar.correct(sentence)

print(result)

# %%
# test Llama explanation
print(
    explain.explain(result)
)

# %%
# test Llama conversation
print(
    conversation.reply(
        "Hello!",
        memory
    )
)

# %%
# test router
tests = [

    "Hello",

    "She go to school yesterday.",

    "Why?",

    "How?",

    "Explain."

]

for t in tests:

    correction = grammar.correct(t)

    task = router.route(
        t,
        correction
    )

    print(t)

    print(task)

    print()

# %%
# test full pipeline
pipeline = Pipeline(
    model,
    tokenizer,
    llama
)

while True:

    text = input("You: ")

    if text.lower() == "exit":
        break

    reply = pipeline.process(text)

    print("Bot:", reply)

# %%
# print memory
for msg in memory.get_history():

    print(msg.role)

    print(msg.content)

    print()
